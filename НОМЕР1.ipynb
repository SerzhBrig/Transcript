# %% [markdown]
# Задание 1

# %% [markdown]
# Причины: 1) Для корректной работы EM и получения надежных оценок параметров модели требуется достаточное количество данных. В некоторых случаях количество образцов RNA-Seq может быть недостаточным для точного оценивания параметров модели, что может привести к неправильным выводам.
# 2)RNA-Seq данные могут содержать выбросы или артефакты, такие как технические ошибки секвенирования или редкие биологические события. Метод EM может быть чувствителен к таким выбросам, что может привести к искаженным оценкам параметров модели.

# %% [markdown]
# Задание 2

# %% [markdown]
# к сожалению работающего код я так и не смог написать, была проблемы с подключением библиотек, он просто слетал каждый раз на второй ячейке

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# if (!requireNamespace("BiocManager", quietly = TRUE))
#     install.packages("BiocManager")
# BiocManager::install("recount3")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/BiocManager_1.30.23.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 589753 bytes (575 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...
